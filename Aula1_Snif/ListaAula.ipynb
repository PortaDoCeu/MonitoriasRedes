# %% [markdown]
# ## **Guia Aula01**
#
# #### **1. Switch**
# * O que é e por que usar um switch
# * Como usar o switch do laboratorio e conectar os dispositivos a ele
# * Configurar IP no painel de controle e usar comando **ipconfig** no cmd
# * Testar comunicação usando comando de **ping** no cmd
#
# #### **2. Sniffer e espelhamento de portas**
# * Explicar a utilidade de um sniffer
# * Necessidade de configurar um switch para espelhar portas.
#
# #### **3. Driver SEL C662**
# * Explicar driver SEL C662 para configurar switch usando console -> Revisar **RJ45, DB9, RS-232**
# * Uso de gerenciador de dispositivos (ver porta COM) e **putty** para enviar comandos
# * Baixar driver SEL C662 da schweitzer
# * Configuração dos pinos **DCE, DTE, GND** e **5V** para fazer comunicação serial com o switch
#
# #### **4. SSH2**
# * Configurar Switch para permitir ssh2
#
# #### **5. Espelhamento de portas**
# * Espelhar portas do switch usando ssh2
# * Testar comunicação com **wireshark**
#
# #### **6. ESP-IDF**
# * Explicar o que é o **ESP-IDF**
# * Por quê usá-lo (comparar com **framework** do arduino)
#
# #### **7. Instalação do ESP-IDF**
# * Instalar extensão do ESP-IDF no VS Code
# * Usar **Ctrl+Shift+P** -> **Reload** depois de instalar a extensão
# * Instalar ESP-IDF usando **EIM** (ESP-IDF Installation Manager)
#
# #### **8. Programação em ESP-IDF**
# * Explicar estrutura de um projeto em ESP-IDF
# * Explicar o **CMaker** no ESP-IDF
# * Explicar o que é **FreeRTOS**
#
# #### **9. Testar Código simples em ESP-IDF**
# * Target: ESP32
# * Board: ESP32-WROVER
#
# #### **10. Apresentar código sniffer para captura de pacotes**
# * Biblioteca para captura de pacotes
# * Base para um sniffer embarcado
# * Tratamento dos dados feito pelo usuário
