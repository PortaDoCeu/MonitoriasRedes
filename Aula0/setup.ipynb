# %% [markdown]
# npm init -y
# npm install typescript @types/node --save-dev
# npx tsc --init
# npm install tsx --save-dev
#
# mkdir src
# echo "console.log('Olá, TypeScript com Node!');" > src/index.ts
#
#   "scripts": {
#     "start": "tsx src/index.ts",
#     "dev": "tsx watch src/index.ts",
#   },
#
# npx tsx src/nome.ts
