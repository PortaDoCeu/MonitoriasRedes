# %% [markdown]
# * Adicionar um novo device (clp) em "Add new device" para ter 2 CLPs no projeto:
#
# ![image.png](attachment:image.png)
#
# * Escolher um dos dois CLPs para ser um "IO device" e criar a interface de rede Profinet IO:
#
# ![image-2.png](attachment:image-2.png)
#
# * Criar uma área de transferência de input e output dos dois CLPs:
#
# ![image-3.png](attachment:image-3.png)
